# %%
# !pip install matlab
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for matlab: filename=matlab-0.1-py3-none-any.whl size=1155 sha256=346497fc0b7d84a7fbb9ef332282311edcf3150e7b5d9b58a74d0b761e9cd3c2
#   Stored in directory: /root/.cache/pip/wheels/d1/d3/76/5314058ee22e7957a18eec0291788462f1df178bb08223bdd2
# Successfully built matlab
# ...
